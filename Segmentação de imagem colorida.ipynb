# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
# amarelo
lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])
# verde
lower_green = np.array([36, 25, 25])
upper_green = np.array([86, 255, 255])
# vermelho
lower_red1 = np.array([0, 70, 50])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([170, 70, 50])
upper_red2 = np.array([180, 255, 255])
# laranja
lower_orange = np.array([10, 100, 100])
upper_orange = np.array([20, 255, 255])
# azul
lower_blue = np.array([100, 60, 60])
upper_blue = np.array([140, 255, 255])

# %%
mask_yellow = cv2.inRange(cv2.cvtColor(img, cv2.COLOR_BGR2HSV), lower_yellow, upper_yellow)
mask_green = cv2.inRange(cv2.cvtColor(img, cv2.COLOR_BGR2HSV), lower_green, upper_green)
mask_red1 = cv2.inRange(cv2.cvtColor(img, cv2.COLOR_BGR2HSV), lower_red1, upper_red1)
mask_red2 = cv2.inRange(cv2.cvtColor(img, cv2.COLOR_BGR2HSV), lower_red2, upper_red2)
mask_red = cv2.bitwise_or(mask_red1, mask_red2)
mask_orange = cv2.inRange(cv2.cvtColor(img, cv2.COLOR_BGR2HSV), lower_orange, upper_orange)
mask_blue = cv2.inRange(cv2.cvtColor(img, cv2.COLOR_BGR2HSV), lower_blue, upper_blue)

yellow_chips = cv2.bitwise_and(img, img, mask=mask_yellow)
green_chips = cv2.bitwise_and(img, img, mask=mask_green)
red_chips = cv2.bitwise_and(img, img, mask=mask_red)
orange_chips = cv2.bitwise_and(img, img, mask=mask_orange)
blue_chips = cv2.bitwise_and(img, img, mask=mask_blue)

# %%
result = np.hstack((red_chips, green_chips, blue_chips, orange_chips, yellow_chips))
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=2590x391 at 0x7F6D8A884FA0>
